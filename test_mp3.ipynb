# %% [markdown]
# # 2. Transcript

# %% [markdown]
# ## 2.1. Install

# %% [markdown]
# ### 2.1.1. Whisper from git

# %%
# OBLIGATORY: comment if not needed
#!pip install git+https://github.com/openai/whisper.git

# %% [markdown]
# ### 2.1.2. ffmpeg for Ubuntu

# %%
# OBLIGATORY: comment if not needed
# !sudo apt install ffmpeg

# %% [markdown]
# ## 2.2. Install test

# %%
import whisper
print(whisper.__file__)

# %% [markdown]
# ## 2.3. Simple test

# %% [markdown]
# ### functions

# %%
import torch
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))
# Out:
# True
# NVIDIA GeForce RTX 4060 Ti

# %%
# !pip uninstall torch torchvision torchaudio -y

# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121
# Out:
# Found existing installation: torch 2.10.0
# Uninstalling torch-2.10.0:
#   Successfully uninstalled torch-2.10.0
# WARNING: Skipping torchvision as it is not installed.
# WARNING: Skipping torchaudio as it is not installed.
# Looking in indexes: https://download.pytorch.org/whl/cu121
# ERROR: Could not find a version that satisfies the requirement torch (from versions: none)
# ERROR: No matching distribution found for torch

# %%
DSCLOUD_KEYWORDS = (
    "Sistema contable DS-CONT para Perú. "
    "Términos frecuentes: RUC, SUNAT, DNI, IGV, MYPE, régimen tributario, estados financieros"
    "plan contable general empresarial, libros electrónicos, PLE, PDT, "
    "asientos contables, amarres contables, asiento de apertura, cierre contable, "
    "hoja electrónica Excel, archivo XML, copia de seguridad, "
    "anticlick, clic derecho, menú lateral, plan de cuentas, "
    "comprobantes de pago, facturas, boletas, notas de crédito, notas de débito, "
    "registro de compras, registro de ventas, libro diario, libro mayor, "
    "balance general, estado de resultados, flujo de caja, DS-CONT Cloud"
    "régimen general, régimen especial, régimen MYPE tributario, RER, RUS, "
    "cronograma tipo A, cronograma tipo B, declaración mensual, declaración anual."
)

def transcribe(video_path, model_name="turbo"):
    import whisper
    import torch

    device = "cuda" if torch.cuda.is_available() else "cpu"

    print(f"\nTRANS: {video_path} with {model_name} model")
    print("-"*20)
    model = whisper.load_model(model_name, device=device)

    result = model.transcribe(video_path , initial_prompt=DSCLOUD_KEYWORDS)
    # result = {"text": <full_trans>, 
    #         "segments": {<timeN-timeN+1: <trans_within_times>,
    #                     <timeN+1-timeN+2: <trans_within_times> ...},
    #         "language": <string>}

    return result["text"]

# %% [markdown]
# # MP3

# %%
video_path = "temp.mp3"

# %%
trans_tiny = None
trans_base = None
trans_small = None
trans_turbo = None
trans_medium = None
trans_large = None

models = {
        "tiny"  : trans_tiny,
        "base"  : trans_base,
        "small" : trans_small,
        "turbo" : trans_turbo,
        "medium": trans_medium,
        "large" : trans_large,
        }

models = {
        "tiny"  : trans_tiny}

for model_name in models.keys():
    models[k] = transcribe(video_path, model_name)
    show_trans(model[k])

# %% [markdown]
# ## Comparisson

# %%
from aux_tasks import compare_two_strings

compare_two_strings(input1=trans_tiny, input2=trans_base, words_number=7, padding=65)

# %% [markdown]
# # Outputs saved

# %%
result_turbo = {'text': " Bienvenido a conocer el sistema contable DS-CONT. La herramienta que les ayudará a procesar y generar la información contable, rendando reportes o portudos, y hace para declaración mensuales anuales o de caras de heridencia para lo portuna toma de decisiones. En el siguiente video desarrollaremos una monografía con diferentes operaciones como podemos visualizar. Con la finalidad de mostrar las mongades del sistema DS-CONT. El flujo de trabajo en ENDS-CONT es la juicidente esquema. Hace uno, creación de empresa. Lo primero que debemos realizar es la creación o apertura de contabilidad. Una de las bondades del sistema es que te permitirá crear de una AN-CONTabilidad sin lint. Hace 2, Configuración del sistema. En esta opción realizaremos las configuraciones básicas o el manejo del sistema, al escon. Plan contable 2020 de acuerdo al ruro de empresa. A más resultados que son los asientos de fino otras veces. Y otras configuraciones adicionales antes del ingreso de información. Fase 3, una vez configurada al empresa, podemos subir información al sistema de dos formas. Forma manual utilizando plantillas tipo forma masiva usando información de una hoja electrónica excel o convertir un archivo XML. Fase 4, generación de reportes. Una vez que se tenga información en el sistema, podemos generar los reportes mensuales anuales o gerenciales. Fase 1, creación de empresa. Para el desarrollo de la monografía, ingresaremos al sistema. Para ello, hay un video de los tengo uno del escrito. Digitamos el usuario que es a un instrador y hacemos clic en la flecha deces. Lo primero que visualizaremos será esta pantalla. Para la creación de empresa, el sistema de este con nuestro pondrá tres modalidades de creación de empresa. Para ello, realizamos antitriz en la parte de la terancia. Obvio, muy bajo la vida. En donde tendremos esas tres opciones de creación de contabilidad. Contabilidad en blanco. Esta modalidad de creación de empresa es desde cero, donde podríamos usar un blanco de blanco de blanco de general empresarial o de estructura distinta al que nos propone el diéxico. Por ejemplo, para una contabilidad financiera usaríamos el blanco de blanco de blanco de blanco de general. Osterior a la creación de esta empresa, realizaremos las configuraciones de plan de cuentas que podemos subir desde una ojexel o de forma manual. Los amarres que es un término nuestro que se refiere a los asientos de estinos o de transferencia y demás para poder trabajar en dicha empresa. Preasión, según un modelo. Como su nombre nos indica, el sistema de este con nuestro pone un modelo en su forma básica. En el que podemos ya trabajar y adicionaremos configuraciones propios de la empresa, como el plan contabil general empresarial, en las cuentas corrientes de bancos u otros. Esta forma se recomienda a los nuevos usuarios puesto que ya podrían trabajar. El sistema propone dos opciones para expresión. El plan contable general empresarial mónificado para las empresas que a partir del 2020 será obligatorio según el armativo. Y en caso, deceremos regularizar empresas para años anteriores, contaremos con el plan contable general empresarial anterior. Contabilidad, según otra contabilidad. En esta forma de creación de empresa, la usamos cuando ya tenemos contabilidad en el sistema. Permitiendo no se aperturar una nueva contabilidad transviriendo datos informativos con. Plan de cuentas, base a tus derrubes, amarres, haciendo tipo operaciones tipo entre otros. Esta opción es utilizada en dos situaciones. Uno, en contabilidades de rubros similares, con la finalidad de minimizar configuraciones iniciales, como el plan contable a más resultados entre otros. Y dos, cuando aperturemos un nuevo año fiscal de la misma empresa, permitiendo no salar el plan contable general empresarial, amarres, plantillas e inclusive el asiento de apertura. Ya que al general el sí recontabde las cuentas del balance, vendría a hacer el asiento de apertura del nuevo año fiscal. Para el desarrollo de la monografía, crearemos la siguiente empresa con los siguientes datos. L'empresa Electronics, empresa comercial dedicada a la venta de equipos de compto y servicios. Es contribuyente del nitetriutario identificado con ruc, 256-3829-1880, cuyo domicilofiscal es en la venida perú, sin número de la provincia y distrito de la venta. Para ello realizamos anticlij en la parte de la terralisquierda de la pantalla. Se le sonamos la opción nueva con la habilidad y la opción desde un modelo. Quienamos los datos solicitados tal es con la venta. En esta opción, es para digital un código particular entre números y letras hasta máximo 11 para que es. Recomendamos que sea un código que nos simplifique los datos de la empresa y aquí al generar copias de seguridad, este será el nombre de la copia de seguridad. En el ejemplo, colocaremos el electrobent. Quienamos campo de rú. Ahora el ejemplo 20-56-3829-68. Podemos hacer cligen el icono de la lupa, el cual tiene la función de recuperar los datos según consulta rucs un acto. El de hace con quién es la abundada de recuperar estos datos de razón social y dirección fiscal si contácemos con un taro. Año contabe. Este es el año para el cual crearemos la contabilidad. Podemos crear también para años anteriores con la finalidad de regularizar las contabilidades. Digitaremos la razón social. El electrónica. Digitaremos la dirección fiscal. Cada indicar que estos tres datos anteriores rú. Razon social. Y dirección se verán reflejados en el encabezado de los libros contables físicos, como registró de compras 20 a entre otros. Campo de observaciones es un campo libre en el cual podemos colocar algún dato relevante de lembreza. Regimen tributari. Colocamos el régimen que corresponde al empresa. Y se ha ni p especial general. Para el ejemplo es mi petrigtar. En el caso que lembreza este obligado de presentar libros elezónicos el sistema cuenta con alertas para su portuna presentación. Para ello indicaremos el tipo de programa que corresponde al empresa. Según el ejemplo, es cronograma tipo A. El sistema cuenta con el plan contable modificado el cual está obligado a partir del 2021. Cuentado tanto como el plan contable anterior para poder regularizar información de años anteriores. Para el ejemplo utilizaremos el nuevo plan. Llevemos el caso de la parte inferior en la parte inferior. Hemos clic en la opción de crear empresa. De esta forma, ya hemos creado la empresa. El cual podemos visualizar en la parte media del sistema.", 'segments': [{'id': 0, 'seek': 0, 'start': 0.0, 'end': 22.0, 'text': ' Bienvenido a conocer el sistema contable DS-CONT. La herramienta que les ayudará a procesar y generar la información contable, rendando reportes o portudos, y hace para declaración mensuales anuales o de caras de heridencia para lo portuna toma de decisiones.', 'tokens': [50364, 16956, 553, 2925, 257, 35241, 806, 13245, 660, 712, 15816, 12, 45541, 51, 13, 2369, 38271, 64, 631, 1512, 20333, 21534, 257, 17565, 289, 288, 1337, 289, 635, 21660, 660, 712, 11, 6125, 1806, 2275, 279, 277, 2436, 35063, 11, 288, 10032, 1690, 16694, 3482, 10923, 901, 279, 364, 901, 279, 277, 368, 1032, 296, 368, 720, 4380, 2755, 1690, 450, 2436, 5051, 39728, 368, 3537, 279, 13, 51464], 'temperature': 0.0, 'avg_logprob': -0.3622625668843587, 'compression_ratio': 1.4395604395604396, 'no_speech_prob': 0.29678642749786377}, {'id': 1, 'seek': 2200, 'start': 22.0, 'end': 33.0, 'text': ' En el siguiente video desarrollaremos una monografía con diferentes operaciones como podemos visualizar.', 'tokens': [50364, 2193, 806, 25666, 960, 32501, 23118, 2002, 1108, 19815, 2686, 416, 17686, 2208, 9188, 2617, 12234, 5056, 9736, 13, 50914], 'temperature': 0.0, 'avg_logprob': -0.3877241015434265, 'compression_ratio': 1.3614457831325302, 'no_speech_prob': 0.5412333011627197}, {'id': 2, 'seek': 2200, 'start': 33.0, 'end': 40.0, 'text': ' Con la finalidad de mostrar las mongades del sistema DS-CONT.', 'tokens': [50914, 2656, 635, 2572, 4580, 368, 21487, 2439, 1108, 70, 2977, 1103, 13245, 15816, 12, 45541, 51, 13, 51264], '
, 11, 2002, 5715, 22192, 1538, 419, 22682, 11, 12234, 34785, 21660, 419, 13245, 368, 4491, 33463, 13, 51614], 'temperature': 0.0, 'avg_logprob': -0.37655269916240985, 'compression_ratio': 1.5082872928176796, 'no_speech_prob': 0.0967337116599083}, {'id': 9, 'seek': 10200, 'start': 102.0, 'end': 113.0, 'text': ' Forma manual utilizando plantillas tipo forma masiva usando información de una hoja electrónica excel o convertir un archivo XML.', 'tokens': [50364, 10126, 64, 9688, 19906, 1806, 3709, 20243, 9746, 8366, 2300, 5931, 29798, 21660, 368, 2002, 1106, 2938, 7072, 1801, 2262, 24015, 277, 7620, 347, 517, 3912, 6340, 1783, 12683, 13, 50914], 'temperature': 0.0, 'avg_logprob': -0.23621906552995955, 'compression_ratio': 1.392156862745098, 'no_speech_prob': 0.20187686383724213}, {'id': 10, 'seek': 10200, 'start': 113.0, 'end': 121.0, 'text': ' Fase 4, generación de reportes. Una vez que se tenga información en el sistema,', 'tokens': [50914, 479, 651, 1017, 11, 1337, 3482, 368, 2275, 279, 13, 15491, 5715, 631, 369, 36031, 21660, 465, 806, 13245, 11, 51314], 'temperature': 0.0, 'avg_logprob': -0.23621906552995955, 'compression_ratio': 1.392156862745098, 'no_speech_prob': 0.20187686383724213}, {'id': 11, 'seek': 12100, 'start': 121.0, 'end': 133.0, 'text': ' podemos generar los reportes mensuales anuales o gerenciales. Fase 1, creación de empresa.', 'tokens': [50364, 12234, 1337, 289, 1750, 2275, 279, 10923, 901, 279, 364, 901, 279, 277, 290, 5170, 1013, 279, 13, 479, 651, 502, 11, 1197, 3482, 368, 22682, 13, 50964], 'temperature': 0.0, 'avg_logprob': -0.4795301498905305, 'compression_ratio': 1.395973154362416, 'no_speech_prob': 0.31650471687316895}, {'id': 12, 'seek': 12100, 'start': 133.0, 'end': 144.0, 'text': ' Para el desarrollo de la monografía, ingresaremos al sistema. Para ello, hay un video de los tengo uno del escrito.', 'tokens': [50964, 11107, 806, 38295, 368, 635, 1108, 19815, 2686, 11, 3957, 495, 23118, 419, 13245, 13, 11107, 33549, 11, 4842, 517, 960, 368, 1750, 13989, 8526, 1103, 4721, 17492, 13, 51514], 'temperature': 0.0, 'avg_logprob': -0.4795301498905305, 'compression_ratio': 1.395973154362416, 'no_speech_prob': 0.31650471687316895}, {'id': 13, 'seek': 14400, 'start': 144.0, 'end': 153.0, 'text': ' Digitamos el usuario que es a un instrador y hacemos clic en la flecha deces.', 'tokens': [50364, 10976, 270, 2151, 806, 32247, 4912, 631, 785, 257, 517, 1058, 6206, 284, 288, 33839, 33661, 465, 635, 7025, 4413, 368, 887, 13, 50814], 'temperature': 0.0, 'avg_logprob': -0.39917021857367624, 'compression_ratio': 1.5603864734299517, 'no_speech_prob': 0.34501633048057556}, {'id': 14, 'seek': 14400, 'start': 153.0, 'end': 164.0, 'text': ' Lo primero que visualizaremos será esta pantalla. Para la creación de empresa, el sistema de este con nuestro pondrá tres modalidades de creación de empresa.', 'tokens': [50814
, 1103, 4808, 16502, 9270, 48028, 36570, 806, 3726, 18586, 13, 51314], 'temperature': 0.0, 'avg_logprob': -0.20873109154079272, 'compression_ratio': 1.6536796536796536, 'no_speech_prob': 0.22623507678508759}, {'id': 26, 'seek': 24900, 'start': 268.0, 'end': 278.0, 'text': ' Y en caso, deceremos regularizar empresas para años anteriores, contaremos con el plan contable general empresarial anterior.', 'tokens': [51314, 398, 465, 9666, 11, 979, 19065, 3890, 9736, 26433, 1690, 11424, 364, 34345, 2706, 11, 660, 23118, 416, 806, 1393, 660, 712, 2674, 13627, 44745, 22272, 13, 51814], 'temperature': 0.0, 'avg_logprob': -0.20873109154079272, 'compression_ratio': 1.6536796536796536, 'no_speech_prob': 0.22623507678508759}, {'id': 27, 'seek': 27800, 'start': 278.0, 'end': 288.0, 'text': ' Contabilidad, según otra contabilidad. En esta forma de creación de empresa, la usamos cuando ya tenemos contabilidad en el sistema.', 'tokens': [50364, 4839, 5177, 4580, 11, 36570, 13623, 660, 5177, 4580, 13, 2193, 5283, 8366, 368, 1197, 3482, 368, 22682, 11, 635, 505, 2151, 7767, 2478, 9914, 660, 5177, 4580, 465, 806, 13245, 13, 50864], 'temperature': 0.0, 'avg_logprob': -0.21564215627209893, 'compression_ratio': 1.5067567567567568, 'no_speech_prob': 0.06144650653004646}, {'id': 28, 'seek': 27800, 'start': 288.0, 'end': 298.0, 'text': ' Permitiendo no se aperturar una nueva contabilidad transviriendo datos informativos con.', 'tokens': [50864, 41006, 270, 7304, 572, 369, 22939, 28586, 2002, 28963, 660, 5177, 4580, 1145, 46551, 7304, 27721, 1356, 36945, 416, 13, 51364], 'temperature': 0.0, 'avg_logprob': -0.21564215627209893, 'compression_ratio': 1.5067567567567568, 'no_speech_prob': 0.06144650653004646}, {'id': 29, 'seek': 29800, 'start': 298.0, 'end': 308.0, 'text': ' Plan de cuentas, base a tus derrubes, amarres, haciendo tipo operaciones tipo entre otros.', 'tokens': [50364, 8112, 368, 46414, 296, 11, 3096, 257, 20647, 1163, 81, 836, 279, 11, 42171, 495, 11, 20509, 9746, 2208, 9188, 9746, 3962, 16422, 13, 50864], 'temperature': 0.0, 'avg_logprob': -0.24337570576728146, 'compression_ratio': 1.576086956521739, 'no_speech_prob': 0.3636871576309204}, {'id': 30, 'seek': 29800, 'start': 308.0, 'end': 313.0, 'text': ' Esta opción es utilizada en dos situaciones.', 'tokens': [50864, 20547, 999, 5687, 785, 19906, 1538, 465, 4491, 2054, 9188, 13, 51114], 'temperature': 0.0, 'avg_logprob': -0.24337570576728146, 'compression_ratio': 1.576086956521739, 'no_speech_prob': 0.3636871576309204}, {'id': 31, 'seek': 29800, 'start': 313.0, 'end': 326.0, 'text': ' Uno, en contabilidades de rubros similares, con la finalidad de minimizar configuraciones iniciales, como el plan contable a más resultados entre otros.', 'tokens': [51114, 37468, 11, 465, 660, 5177, 10284, 368, 5915, 2635, 1034, 7371, 495, 11, 416, 635, 2572, 4580, 368, 4464, 9736, 22192, 9188, 44076, 279, 11, 2617, 806, 1393, 660, 712, 257, 3573, 36796, 3962, 16422, 13
.0, 'avg_logprob': -0.41345678311642087, 'compression_ratio': 1.5084745762711864, 'no_speech_prob': 0.14069624245166779}, {'id': 37, 'seek': 38100, 'start': 381.0, 'end': 389.0, 'text': ' Para ello realizamos anticlij en la parte de la terralisquierda de la pantalla.', 'tokens': [50364, 11107, 33549, 22828, 2151, 49172, 75, 1718, 465, 635, 6975, 368, 635, 1796, 2155, 271, 358, 811, 2675, 368, 635, 44449, 13, 50764], 'temperature': 0.0, 'avg_logprob': -0.39473915100097656, 'compression_ratio': 1.5263157894736843, 'no_speech_prob': 0.08756622672080994}, {'id': 38, 'seek': 38100, 'start': 389.0, 'end': 396.0, 'text': ' Se le sonamos la opción nueva con la habilidad y la opción desde un modelo.', 'tokens': [50764, 1100, 476, 1872, 2151, 635, 999, 5687, 28963, 416, 635, 36565, 4580, 288, 635, 999, 5687, 10188, 517, 27825, 13, 51114], 'temperature': 0.0, 'avg_logprob': -0.39473915100097656, 'compression_ratio': 1.5263157894736843, 'no_speech_prob': 0.08756622672080994}, {'id': 39, 'seek': 38100, 'start': 396.0, 'end': 401.0, 'text': ' Quienamos los datos solicitados tal es con la venta.', 'tokens': [51114, 2326, 1053, 2151, 1750, 27721, 23665, 270, 4181, 4023, 785, 416, 635, 6931, 64, 13, 51364], 'temperature': 0.0, 'avg_logprob': -0.39473915100097656, 'compression_ratio': 1.5263157894736843, 'no_speech_prob': 0.08756622672080994}, {'id': 40, 'seek': 38100, 'start': 401.0, 'end': 409.0, 'text': ' En esta opción, es para digital un código particular entre números y letras hasta máximo 11 para que es.', 'tokens': [51364, 2193, 5283, 999, 5687, 11, 785, 1690, 4562, 517, 44195, 1729, 3962, 36545, 288, 718, 3906, 10764, 38876, 2975, 1690, 631, 785, 13, 51764], 'temperature': 0.0, 'avg_logprob': -0.39473915100097656, 'compression_ratio': 1.5263157894736843, 'no_speech_prob': 0.08756622672080994}, {'id': 41, 'seek': 40900, 'start': 409.0, 'end': 417.0, 'text': ' Recomendamos que sea un código que nos simplifique los datos de la empresa y aquí al generar copias de seguridad,', 'tokens': [50364, 1300, 1112, 521, 2151, 631, 4158, 517, 44195, 631, 3269, 6883, 28134, 1750, 27721, 368, 635, 22682, 288, 6661, 419, 1337, 289, 2971, 4609, 368, 35415, 11, 50764], 'temperature': 0.0, 'avg_logprob': -0.37471379552568707, 'compression_ratio': 1.3945578231292517, 'no_speech_prob': 0.11338897794485092}, {'id': 42, 'seek': 40900, 'start': 417.0, 'end': 425.0, 'text': ' este será el nombre de la copia de seguridad. En el ejemplo, colocaremos el electrobent.', 'tokens': [50764, 4065, 16502, 806, 13000, 368, 635, 2971, 654, 368, 35415, 13, 2193, 806, 13358, 11, 1173, 905, 23118, 806, 7072, 996, 317, 13, 51164], 'temperature': 0.0, 'avg_logprob': -0.37471379552568707, 'compression_ratio': 1.3945578231292517, 'no_speech_prob': 0.11338897794485092}, {'id': 43, 'seek': 42500, 'start': 426.0, 'end': 429.0, 'text': ' Quienamos campo de rú
 'temperature': 0.0, 'avg_logprob': -0.37609227498372394, 'compression_ratio': 1.6403940886699508, 'no_speech_prob': 0.2652405798435211}, {'id': 60, 'seek': 51500, 'start': 528.0, 'end': 538.0, 'text': ' En el caso que lembreza este obligado de presentar libros elezónicos el sistema cuenta con alertas para su portuna presentación.', 'tokens': [51014, 2193, 806, 9666, 631, 7495, 2672, 2394, 4065, 9270, 1573, 368, 1974, 289, 4939, 329, 806, 4371, 1801, 9940, 806, 13245, 17868, 416, 9615, 296, 1690, 459, 2436, 5051, 1974, 3482, 13, 51514], 'temperature': 0.0, 'avg_logprob': -0.37609227498372394, 'compression_ratio': 1.6403940886699508, 'no_speech_prob': 0.2652405798435211}, {'id': 61, 'seek': 51500, 'start': 538.0, 'end': 542.0, 'text': ' Para ello indicaremos el tipo de programa que corresponde al empresa.', 'tokens': [51514, 11107, 33549, 4694, 23118, 806, 9746, 368, 21846, 631, 6805, 68, 419, 22682, 13, 51714], 'temperature': 0.0, 'avg_logprob': -0.37609227498372394, 'compression_ratio': 1.6403940886699508, 'no_speech_prob': 0.2652405798435211}, {'id': 62, 'seek': 54200, 'start': 542.0, 'end': 546.0, 'text': ' Según el ejemplo, es cronograma tipo A.', 'tokens': [50364, 21595, 9453, 806, 13358, 11, 785, 941, 266, 12820, 64, 9746, 316, 13, 50564], 'temperature': 0.0, 'avg_logprob': -0.20714486611855998, 'compression_ratio': 1.4607329842931938, 'no_speech_prob': 0.15339915454387665}, {'id': 63, 'seek': 54200, 'start': 546.0, 'end': 556.0, 'text': ' El sistema cuenta con el plan contable modificado el cual está obligado a partir del 2021.', 'tokens': [50564, 2699, 13245, 17868, 416, 806, 1393, 660, 712, 1072, 1089, 1573, 806, 10911, 3192, 9270, 1573, 257, 13906, 1103, 7201, 13, 51064], 'temperature': 0.0, 'avg_logprob': -0.20714486611855998, 'compression_ratio': 1.4607329842931938, 'no_speech_prob': 0.15339915454387665}, {'id': 64, 'seek': 54200, 'start': 556.0, 'end': 564.0, 'text': ' Cuentado tanto como el plan contable anterior para poder regularizar información de años anteriores.', 'tokens': [51064, 13205, 317, 1573, 10331, 2617, 806, 1393, 660, 712, 22272, 1690, 8152, 3890, 9736, 21660, 368, 11424, 364, 34345, 2706, 13, 51464], 'temperature': 0.0, 'avg_logprob': -0.20714486611855998, 'compression_ratio': 1.4607329842931938, 'no_speech_prob': 0.15339915454387665}, {'id': 65, 'seek': 54200, 'start': 564.0, 'end': 568.0, 'text': ' Para el ejemplo utilizaremos el nuevo plan.', 'tokens': [51464, 11107, 806, 13358, 19906, 23118, 806, 18591, 1393, 13, 51664], 'temperature': 0.0, 'avg_logprob': -0.20714486611855998, 'compression_ratio': 1.4607329842931938, 'no_speech_prob': 0.15339915454387665}, {'id': 66, 'seek': 56800, 'start': 569.0, 'end': 572.0, 'text': ' Llevemos el caso de la parte inferior en la parte inferior.', 'tokens': [50414, 441, 306, 303, 3415, 806, 9666, 368, 635, 6975, 24249, 465, 635, 6975, 24249, 13, 50564], 'temperature': 0.0, 'avg_logprob': -0.6977020789837015, 'compression_ratio': 1.5149253731343284, 'no_speech_prob': 0.1706327348947525}, {'id': 67, 'seek': 56800, 'start': 572.0, 'end': 577.0, 'text': ' Hemos clic en la opción de crear empresa.', 'tokens': [50564, 389, 4485, 33661, 465, 635, 999, 5687, 368, 31984, 22682, 13, 50814], 'temperature': 0.0, 'avg_logprob': -0.6977020789837015, 'compression_ratio': 1.5149253731343284, 'no_speech_prob': 0.1706327348947525}, {'id': 68, 'seek': 56800, 'start': 577.0, 'end': 580.0, 'text': ' De esta forma, ya hemos creado la empresa.', 'tokens': [50814, 1346, 5283, 8366, 11, 2478, 15396, 1197, 1573, 635, 22682, 13, 50964], 'temperature': 0.0, 'avg_logprob': -0.6977020789837015, 'compression_ratio': 1.5149253731343284, 'no_speech_prob': 0.1706327348947525}, {'id': 69, 'seek': 56800, 'start': 580.0, 'end': 586.0, 'text': ' El cual podemos visualizar en la parte media del sistema.', 'tokens': [50964, 2699, 10911, 12234, 5056, 9736, 465, 635, 6975, 3021, 1103, 13245, 13, 51264], 'temperature': 0.0, 'avg_logprob': -0.6977020789837015, 'compression_ratio': 1.5149253731343284, 'no_speech_prob': 0.1706327348947525}], 'language': 'es'}

# %%
trans_turbo = '''
Bienvenido a conocer el sistema contable DS-CONT. La herramienta que les ayudará a procesar y generar la información contable brindando reportes oportunos, ya sea para declaraciones mensuales, anuales o de carácter gerencial, para la oportuna toma de decisiones. En el siguiente video desarrollaremos una monografía con diferentes operaciones como podemos visualizar. Con la finalidad de mostrar las bondades del sistema DS-CONT. El flujo de trabajo en el DS-CONT es bajo el siguiente esquema. Fase 1. Creación de empresa. Lo primero que debemos realizar es la creación o apertura de contabilidad. Una de las bondades del sistema es que te permitirá crear de una a n contabilidades, sin límite. Fase 2. Configuración del sistema. En esta opción realizaremos las configuraciones básicas para el manejo del sistema, tales como Plan Contable 2020 de acuerdo al rubro de empresa. Amarres contables. Amarres contables, que son los asientos de fino o transferencia. Y otras configuraciones adicionales, antes del ingreso de información. Fase 3. Una vez configurada la empresa, podemos subir información al sistema de dos formas. Forma manual, utilizando plantillas tipo, forma masiva, usando información de una hoja electrónica Excel o convertir un archivo XML. Fase 4. Generación de reportes. Una vez que se tenga información en el sistema, ya podemos generar los reportes mensuales, anuales o gerenciales. Fase 1. Creación de empresa. Para el desarrollo de la monografía, ingresaremos al sistema. Para ello, editaremos el icono del escritor. Digitamos el usuario que es administrador y hacemos clic en la flecha de acceso. Lo primero que visualizaremos será esta pantalla. Para la creación de empresa, el sistema DS-CON nos propondrá tres modalidades de creación de empresa. Para ello, realizamos anticlip en la parte lateral izquierda. Opción Nueva Contabilidad. En donde tendremos estas tres opciones de creación de contabilidad. Contabilidad en blanco. Esta modalidad de creación de empresa es desde cero, donde podremos usar un plan contable distinto del plan contable general empresarial, o de estructura distinta al que nos propone el DS-CON. Por ejemplo, para una contabilidad financiera, usaríamos el plan contable financiero. Posterior a la creación de esta empresa, realizaremos las configuraciones de plan de cuentas, que podemos subir desde una hoja Excel o de forma manual. Los amarres, que es un término nuestro, que se refiere a los asientos de destino o de transferencia, y demás para poder trabajar en dicha empresa. Creación según un modelo. Como su nombre nos indica, el sistema DS-CON nos propone un modelo en su forma básica, en el que podemos ya trabajar. Y adicionaremos configuraciones propias de la empresa, como el plan contable general empresarial, en las cuentas corrientes de bancos u otros. Esta forma se recomienda a los nuevos usuarios, puesto que ya podrían trabajar. El sistema propone dos opciones para su creación. El plan contable general empresarial modificado, para las empresas que a partir del 2020, será obligatorio según normativa. Y en caso deseemos regularizar empresas para años anteriores, contaremos con el plan contable general empresarial anterior. Contabilidad según otra contabilidad. En esta forma de creación de empresa, la usamos cuando ya tenemos contabilidades en el sistema, permitiéndonos aperturar una nueva contabilidad transfiriendo datos informativos como plan de cuentas, base de datos de rubro, amarres, asientos tipo, operaciones tipo, entre otros. Esta opción es utilizada en dos situaciones. Uno, en contabilidades de rubros similares, con la finalidad de minimizar configuraciones iniciales, como el plan contable, amarres contables, entre otros. Y dos, cuando aperturemos un nuevo año fiscal de la misma empresa, permitiéndonos jalar el plan contable general empresarial, amarres, plantillas e inclusive el asiento de apertura, ya que al generar el cierre contable de las cuentas del balance, vendrían a ser el asiento de apertura del nuevo año fiscal. Para el desarrollo de la monografía, crearemos la siguiente empresa con los siguientes datos. La empresa Electronic SAC, empresa comercial dedicada a la venta de equipos de cómputo y servicios. Es contribuyente del MIP tributario, identificado con RUC 20563829680, cuyo domicilio fiscal es en la avenida Perú, sin número, de la provincia y distrito del departamento del Cusco. Para ello, realizamos anticlick en la parte lateral izquierda de la pantalla. Seleccionamos la opción Nueva Contabilidad y la opción Desde un modelo. Llenamos los datos solicitados tales como Contabilidad. En esta opción es para digitar un código particular entre números y letras hasta máximo 11 caracteres. Recomendamos que sea un código que nos simplifique los datos de la empresa, ya que al generar copias de seguridad, este será el nombre de la copia de seguridad. En el ejemplo, colocaremos Electro 20. Llenamos campo de RUC. Para el ejemplo, 20563829680. Podemos hacer clic en el ícono de la lupa, el cual tiene la función de recuperar los datos según consulta RUC SUNAT. El DCCON tiene la bondad de recuperar estos datos de razón social y dirección fiscal si contásemos con Internet. Año Contable Es el año para el cual crearemos la contabilidad. Podemos crear también para años anteriores con la finalidad de regularizar las contabilidades. Digitaremos la razón social. Electronic Sack Digitaremos la dirección fiscal. Cabe indicar que estos tres datos anteriores, RUC, razón social y dirección, se verán reflejados en el encabezado de los libros contables físicos, como registro de compras, ventas, entre otros. Campo de observaciones. Es un campo libre en el cual podemos colocar algún dato relevante de la empresa. Régimen tributario. Colocamos el régimen que corresponde a la empresa. Ya sea NIP, especial, general. Para el ejemplo, es NIP tributario. En el caso que la empresa esté obligado de presentar libros electrónicos, el sistema cuenta con alertas para su oportuna presentación. Para ello, indicaremos el tipo de cronograma que corresponde a la empresa. Según el ejemplo, cronograma tipo A. El sistema cuenta con el plan contable modificado, el cual está obligado a partir del 2020. Cuenta tanto como el plan contable anterior para poder regularizar información de años anteriores. Para el ejemplo, utilizaremos el nuevo plan. Llenado todos los datos, en la parte inferior, hacemos clic en la opción crear empresa. De esta forma, ya hemos creado la empresa, el cual podemos visualizar en la parte media del sistema.
'''
